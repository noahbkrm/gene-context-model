# %%
# %cd gene-context-model
# Out:
# [Errno 2] No such file or directory: 'gene-context-model'
# /content/gene-context-model/src/model

# %%
# %cd ..
# Out:
# /content/gene-context-model

# %%
from google.colab import drive
drive.mount("/content/drive")

# %cd /content

# !git clone https://github.com/noahbkrm/gene-context-model.git

# %cd gene-context-model

# %%
# !cd data
# !unzip -q "/content/drive/MyDrive/gcm/processed.zip" -d data/
# !cd ..

# %%
# !cd /content/gene-context-model
# !git pull
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 3.49 KiB | 1.75 MiB/s, done.
# From https://github.com/noahbkrm/gene-context-model
#    6573c70..9327a94  main       -> origin/main
# Updating 6573c70..9327a94
# Fast-forward
#  src/model/rna_encoder.py |   6 +++
#  src/model/run.ipynb      | 131 ++++++++++++++++++++++++++++++++++++++++++++---
#  2 files changed, 129 insertions(+), 8 deletions(-)

# %%
# %cd src/model
# !free -h
# Out:
# /content/gene-context-model/src/model
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       6.5Gi       3.8Gi        16Mi       2.4Gi       5.8Gi
# Swap:             0B          0B          0B

# %%
# %run train.py
# Out:
# TRAIN.PY STARTED
# started return
# loading clinical
# clinical done
# loading cnv
# cnv done
# loading snv
# snv done
# loading rna
# rna done
# data loaded
# reduced genes
# dedup
# aligned
# Keeping 1990 of 2000 genes (removed 10 low-variance genes)
# low
# Memory usage:
# dataset ready
# RnaStats Done
# Dataset prepared
#
# Epoch 1/15
# Training:   0%|          | 0/2145 [00:00<?, ?it/s]
# torch.Size([4, 1990, 768])
# torch.float32
# cuda:0
# 23.3203125 MB
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /content/gene-context-model/src/model/train.py in <module>
#     368         print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")
#     369
# --> 370         loss = training(
#     371             teacher_model,
#     372             student_model,
#
# /content/gene-context-model/src/model/train.py in training(teacher_model, student_model, teacher_tokenizer, student_tokenizer, loader, optimizer, scaler, masker, teacher_center, ema_param)
#     171                 teacher = teacher_model(teacher_tokens) # Calculate teacher
#     172
# --> 173             student = student_model(student_tokens)
#     174
#     175             z_teacher = teacher["projection"]
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/gene_model.py in forward(self, gene_tokens)
#      51     def __init__(self, n_genes, hidden_dim: int = HIDDEN_DIM, method: str = "Sparse"):
#      52         super().__init__()
# ---> 53         self.projection = Projection(hidden_dim)
#      54         if method == "Sparse":
#      55             self.transformer = SparseTransformerEncoder(n_genes)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/transformer.py in forward(self, x)
#     132
#     133         for block in self.blocks:
# --> 134             x = block(x)
#     135
#     136         return x
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/transformer.py in forward(self, x)
#     107         x_norm1 = self.norm1(x)
#     108
# --> 109         attn_out = self.sparse_attn(
#     110             x_norm1
#     111         )
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/sparse_attention.py in forward(self, input_tokens)
#      73
#      74             nbrs = self.neighbor_index[gene]      # (K,)
# ---> 75
#      76             # Gather projected neighbors
#      77             K = K_all[:, nbrs]                    # (B, K, H)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     132         Runs the forward pass.
#     133         """
# --> 134         return F.linear(input, self.weight, self.bias)
#     135
#     136     def extra_repr(self) -> str:
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 748.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 649.81 MiB is free. Including non-PyTorch memory, this process has 13.93 GiB memory in use. Of the allocated memory 13.62 GiB is allocated by PyTorch, and 180.76 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
