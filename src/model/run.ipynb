# %%
# %cd gene-context-model
# !git fetch origin
# !git switch sparse-inf-att
# Out:
# /content/gene-context-model
# Branch 'sparse-inf-att' set up to track remote branch 'sparse-inf-att' from 'origin'.
# Switched to a new branch 'sparse-inf-att'

# %%
from google.colab import drive
drive.mount("/content/drive")

# %cd /content

# !git clone https://github.com/noahbkrm/gene-context-model.git

# %cd gene-context-model
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# fatal: destination path 'gene-context-model' already exists and is not an empty directory.
# /content/gene-context-model

# %%
# %pwd
# !cd data
# !unzip -q "/content/drive/MyDrive/gcm/processed.zip" -d data/
# !cd ..
# Out:
# '/content/gene-context-model'

# %%
# !cd /content/gene-context-model
# !git pull

# %%
# %cd src/model
# !free -h
# Out:
# /content/gene-context-model/src/model
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       827Mi       7.0Gi       2.0Mi       4.8Gi        11Gi
# Swap:             0B          0B          0B

# %%
# %run train.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/gene-context-model/src/model/train.py in <module>
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import pandas as pd
#       4 from tqdm import tqdm
#       5 from constants import *
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in <module>
#    2227
#    2228 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2229 from torch import _VF as _VF, functional as functional  # usort: skip
#    2230 from torch.functional import *  # usort: skip # noqa: F403
#    2231
#
# /usr/local/lib/python3.12/dist-packages/torch/functional.py in <module>
#       6
#       7 import torch
# ----> 8 import torch.nn.functional as F
#       9 from torch import _VF, Tensor
#      10 from torch._C import _add_docstr
#
# ...
