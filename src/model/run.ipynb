# %%
# %cd gene-context-model

# %%
# %cd ..

# %%
from google.colab import drive
drive.mount("/content/drive")

# %cd /content

# !git clone https://github.com/noahbkrm/gene-context-model.git

# %cd gene-context-model

# %%
# !cd data
# !unzip -q "/content/drive/MyDrive/gcm/processed.zip" -d data/
# !cd ..

# %%
# !cd /content/gene-context-model
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 361 bytes | 361.00 KiB/s, done.
# From https://github.com/noahbkrm/gene-context-model
#    028d4ee..52d7bba  main       -> origin/main
# Updating 028d4ee..52d7bba
# Fast-forward
#  src/model/train.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# %cd src/model
# !free -h
# Out:
# [Errno 2] No such file or directory: 'src/model'
# /content/gene-context-model/src/model
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       5.7Gi       3.7Gi        16Mi       3.2Gi       6.7Gi
# Swap:             0B          0B          0B

# %%
# %run train.py
# Out:
# TRAIN.PY STARTED
# started return
# data loaded
# reduced genes
# dedup
# aligned
# Keeping 1493 of 1500 genes (removed 7 low-variance genes)
# low
# dataset ready
# RnaStats Done
# Dataset prepared
# models initialized
#
# Epoch 1/15
# Training:   0%|          | 0/2145 [00:00<?, ?it/s]
# DINO: 5.470902919769287
# Var : 0.2065090537071228
# Cov : 0.00034826723276637495
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/gene-context-model/src/model/train.py in <module>
#     361         print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")
#     362
# --> 363         loss = training(
#     364             teacher_model,
#     365             student_model,
#
# /content/gene-context-model/src/model/train.py in training(teacher_model, student_model, teacher_tokenizer, student_tokenizer, loader, optimizer, scaler, masker, teacher_center, ema_param)
#     161
#     162             with torch.no_grad():
# --> 163                 teacher = teacher_model(teacher_tokens) # Calculate teacher
#     164
#     165             student = student_model(student_tokens)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/gene_model.py in forward(self, gene_tokens)
#      52
#      53     def forward(self, gene_tokens): # image_binary: True is student, False is teacher
# ---> 54         transformed_emb = self.transformer(gene_tokens)
#      55
#      56         """ print(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/transformer.py in forward(self, x)
#     132
#     133         for block in self.blocks:
# --> 134             x = block(x)
#     135
#     136         return x
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/transformer.py in forward(self, x)
#     107         x_norm1 = self.norm1(x)
#     108
# --> 109         attn_out = self.sparse_attn(
#     110             x_norm1
#     111         )
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/sparse_attention.py in forward(self, input_tokens)
#      78
#      79             scores = (
# ---> 80                 q.unsqueeze(1) * K
#      81             ).sum(dim=-1)
#      82
#
# KeyboardInterrupt:
