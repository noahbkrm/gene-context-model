# %%
# %cd gene-context-model
# Out:
# [Errno 2] No such file or directory: 'gene-context-model'
# /content

# %%
# %cd ..

# %%
from google.colab import drive
drive.mount("/content/drive")

# %cd /content

# !git clone https://github.com/noahbkrm/gene-context-model.git

# %cd gene-context-model
# Out:
# Mounted at /content/drive
# /content
# Cloning into 'gene-context-model'...
# remote: Enumerating objects: 510, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 510 (delta 105), reused 120 (delta 48), pack-reused 326 (from 1)
# Receiving objects: 100% (510/510), 3.62 MiB | 7.90 MiB/s, done.
# Resolving deltas: 100% (295/295), done.
# /content/gene-context-model

# %%
# !cd data
# !unzip -q "/content/drive/MyDrive/gcm/processed.zip" -d data/
# !cd ..
# Out:
# /bin/bash: line 1: cd: data: No such file or directory

# %%
# !cd /content/gene-context-model
# !git pull

# %%
# %cd src/model
# !free -h
# Out:
# /content/gene-context-model/src/model
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       840Mi       6.7Gi       2.0Mi       5.1Gi        11Gi
# Swap:             0B          0B          0B

# %%
# %run train.py
# Out:
# TRAIN.PY STARTED
# started return
# data loaded
# reduced genes
# dedup
# aligned
# Keeping 1493 of 1500 genes (removed 7 low-variance genes)
# low
# dataset ready
# RnaStats Done
# Dataset prepared
# models initialized
#
# Epoch 1/15
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/gene-context-model/src/model/train.py in <module>
#     361         print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")
#     362
# --> 363         loss = training(
#     364             teacher_model,
#     365             student_model,
#
# /content/gene-context-model/src/model/train.py in training(teacher_model, student_model, teacher_tokenizer, student_tokenizer, loader, optimizer, scaler, masker, teacher_center, ema_param)
#     170             # Apply softmax and temp, then calculate cross-entropy loss
#     171             teacher_logits = (
# --> 172                 z_teacher - teacher_center.center
#     173             ) / T_TEACHER
#     174
#
# RuntimeError: The size of tensor a (256) must match the size of tensor b (85) at non-singleton dimension 2
