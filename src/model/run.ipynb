# %%
# %cd gene-context-model
# Out:
# /content/gene-context-model

# %%
# %cd ..
# Out:
# /content

# %%
from google.colab import drive
drive.mount("/content/drive")

# %cd /content

# !git clone https://github.com/noahbkrm/gene-context-model.git

# %cd gene-context-model
# Out:
# Mounted at /content/drive
# /content
# Cloning into 'gene-context-model'...
# remote: Enumerating objects: 475, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 475 (delta 84), reused 99 (delta 41), pack-reused 326 (from 1)
# Receiving objects: 100% (475/475), 3.62 MiB | 7.75 MiB/s, done.
# Resolving deltas: 100% (274/274), done.
# /content/gene-context-model

# %%
# !cd data
# !unzip -q "/content/drive/MyDrive/gcm/processed.zip" -d data/
# !cd ..
# Out:
# /bin/bash: line 1: cd: data: No such file or directory

# %%
# !cd /content/gene-context-model
# !git pull
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 6 (delta 4), reused 6 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 435 bytes | 217.00 KiB/s, done.
# From https://github.com/noahbkrm/gene-context-model
#    982ceef..b8d02ed  main       -> origin/main
# Updating 982ceef..b8d02ed
# Fast-forward
#  src/model/constants.py | 2 +-
#  src/model/train.py     | 7 +------
#  2 files changed, 2 insertions(+), 7 deletions(-)

# %%
# %cd src/model
# !free -h
# Out:
# [Errno 2] No such file or directory: 'src/model'
# /content/gene-context-model/src/model
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       5.5Gi       1.6Gi        16Mi       5.6Gi       6.9Gi
# Swap:             0B          0B          0B

# %%
# %run train.py
# Out:
# TRAIN.PY STARTED
# started return
# data loaded
# reduced genes
# dedup
# aligned
# Keeping 1990 of 2000 genes (removed 10 low-variance genes)
# low
# Memory usage:
# dataset ready
# RnaStats Done
# Dataset prepared
# models initialized
#
# Epoch 1/15
# Training:   0%|          | 0/8577 [00:00<?, ?it/s]
# RNA done
# SNV done
# RNA done
# SNV done
# DINO: 5.4972968101501465
# Var : 0.21061888337135315
# Cov : 0.0004285313771106303
# Training:   0%|          | 1/8577 [00:10<23:58:08, 10.06s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 2/8577 [00:18<22:20:48,  9.38s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 3/8577 [00:27<20:54:16,  8.78s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 4/8577 [00:36<21:08:08,  8.88s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 5/8577 [00:45<21:15:16,  8.93s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 6/8577 [00:53<20:32:23,  8.63s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 7/8577 [01:02<20:58:41,  8.81s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 8/8577 [01:10<20:51:45,  8.76s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 9/8577 [01:19<20:44:01,  8.71s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 10/8577 [01:28<21:01:31,  8.84s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 11/8577 [01:37<20:54:34,  8.79s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# Training:   0%|          | 12/8577 [01:45<20:45:00,  8.72s/it]
# RNA done
# SNV done
# RNA done
# SNV done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/gene-context-model/src/model/train.py in <module>
#     360         print(f"\nEpoch {epoch+1}/{NUM_EPOCHS}")
#     361
# --> 362         loss = training(
#     363             teacher_model,
#     364             student_model,
#
# /content/gene-context-model/src/model/train.py in training(teacher_model, student_model, teacher_tokenizer, student_tokenizer, loader, optimizer, scaler, masker, teacher_center, ema_param)
#     161
#     162             with torch.no_grad():
# --> 163                 teacher = teacher_model(teacher_tokens) # Calculate teacher
#     164
#     165             student = student_model(student_tokens)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/gene_model.py in forward(self, gene_tokens)
#      58
#      59     def forward(self, gene_tokens): # image_binary: True is student, False is teacher
# ---> 60         transformed_emb = self.transformer(gene_tokens)
#      61
#      62         """ print(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/transformer.py in forward(self, x)
#     132
#     133         for block in self.blocks:
# --> 134             x = block(x)
#     135
#     136         return x
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/transformer.py in forward(self, x)
#     107         x_norm1 = self.norm1(x)
#     108
# --> 109         attn_out = self.sparse_attn(
#     110             x_norm1
#     111         )
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /content/gene-context-model/src/model/sparse_attention.py in forward(self, input_tokens)
#      78
#      79             scores = (
# ---> 80                 q.unsqueeze(1) * K
#      81             ).sum(dim=-1)
#      82
#
# KeyboardInterrupt:
